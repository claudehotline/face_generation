# %% [markdown]
# # 人脸生成（Face Generation）
# 在该项目中，你将使用生成式对抗网络（Generative Adversarial Nets）来生成新的人脸图像。
# ### 获取数据
# 该项目将使用以下数据集：
# - MNIST
# - CelebA
#
# 由于 CelebA 数据集比较复杂，而且这是你第一次使用 GANs。我们想让你先在 MNIST 数据集上测试你的 GANs 模型，以让你更快的评估所建立模型的性能。
#
# 如果你在使用 [FloydHub](https://www.floydhub.com/), 请将 `data_dir` 设置为 "/input" 并使用 [FloydHub data ID](http://docs.floydhub.com/home/using_datasets/) "R5KrjnANiKVhLWAkpXhNBe".

# %%
data_dir = './data'

# FloydHub - Use with data ID "R5KrjnANiKVhLWAkpXhNBe"
#data_dir = '/input'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper

helper.download_extract('mnist', data_dir)
helper.download_extract('celeba', data_dir)
# Out:
# Found mnist Data
# Found celeba Data

# %% [markdown]
# ## 探索数据（Explore the Data）
# ### MNIST
# [MNIST](http://yann.lecun.com/exdb/mnist/) 是一个手写数字的图像数据集。你可以更改 `show_n_images` 探索此数据集。

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
import os
from glob import glob
from matplotlib import pyplot

mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'mnist/*.jpg'))[:show_n_images], 28, 28, 'L')
pyplot.imshow(helper.images_square_grid(mnist_images, 'L'), cmap='gray')

# %% [markdown]
# ### CelebA
# [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) 是一个包含 20 多万张名人图片及相关图片说明的数据集。你将用此数据集生成人脸，不会用不到相关说明。你可以更改 `show_n_images` 探索此数据集。

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'img_align_celeba/*.jpg'))[:show_n_images], 28, 28, 'RGB')
pyplot.imshow(helper.images_square_grid(mnist_images, 'RGB'))

# %% [markdown]
# ## 预处理数据（Preprocess the Data）
# 由于该项目的重点是建立 GANs 模型，我们将为你预处理数据。
#
# 经过数据预处理，MNIST 和 CelebA 数据集的值在 28×28 维度图像的 [-0.5, 0.5] 范围内。CelebA 数据集中的图像裁剪了非脸部的图像部分，然后调整到 28x28 维度。
#
# MNIST 数据集中的图像是单[通道](https://en.wikipedia.org/wiki/Channel_(digital_image%29)的黑白图像，CelebA 数据集中的图像是 [三通道的 RGB 彩色图像](https://en.wikipedia.org/wiki/Channel_(digital_image%29#RGB_Images)。
#
# ## 建立神经网络（Build the Neural Network）
# 你将通过部署以下函数来建立 GANs 的主要组成部分:
# - `model_inputs`
# - `discriminator`
# - `generator`
# - `model_loss`
# - `model_opt`
# - `train`
#
# ### 检查 TensorFlow 版本并获取 GPU 型号
# 检查你是否使用正确的 TensorFlow 版本，并获取 GPU 型号

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.0'), 'Please use TensorFlow version 1.0 or newer.  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.0.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ### 输入（Input）
# 部署 `model_inputs` 函数以创建用于神经网络的 [占位符 (TF Placeholders)](https://www.tensorflow.org/versions/r0.11/api_docs/python/io_ops/placeholders)。请创建以下占位符：
# - 输入图像占位符: 使用 `image_width`，`image_height` 和 `image_channels` 设置为 rank 4。
# - 输入 Z 占位符: 设置为 rank 2，并命名为 `z_dim`。
# - 学习速率占位符: 设置为 rank 0。
#
# 返回占位符元组的形状为 (tensor of real input images, tensor of z data, learning rate)。

# %%
import problem_unittests as tests

def model_inputs(image_width, image_height, image_channels, z_dim):
    """
    Create the model inputs
    :param image_width: The input image width
    :param image_height: The input image height
    :param image_channels: The number of image channels
    :param z_dim: The dimension of Z
    :return: Tuple of (tensor of real input images, tensor of z data, learning rate)
    """
    # TODO: Implement Function
    input_image = tf.placeholder(tf.float32, [None, image_width, image_height, image_channels], name='input_image')
    z_input = tf.placeholder(tf.float32, [None, z_dim], name='z_input')
    learning_rate = tf.placeholder(tf.float32, name='learning_rate')
    
    return (input_image, z_input, learning_rate)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### 辨别器（Discriminator）
# 部署 `discriminator` 函数创建辨别器神经网络以辨别 `images`。该函数应能够重复使用神经网络中的各种变量。 在 [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) 中使用 "discriminator" 的变量空间名来重复使用该函数中的变量。
#
# 该函数应返回形如 (tensor output of the discriminator, tensor logits of the discriminator) 的元组。

# %%
def discriminator(images, reuse=False):
    """
    Create the discriminator network
    :param image: Tensor of input image(s)
    :param reuse: Boolean if the weights should be reused
    :return: Tuple of (tensor output of the discriminator, tensor logits of the discriminator)
    """
    # TODO: Implement Function
    #alpha = 0.2
    
    with tf.variable_scope('discriminator', reuse=reuse):
        x1 = tf.layers.conv2d(images, 64, 5, strides=2, padding='same')
        relu1 = tf.maximum(0.2 * x1, x1)
    
        x2 = tf.layers.conv2d(relu1, 128, 5, strides=2, padding='same')
        bn2 = tf.layers.batch_normalization(x2, training=True)
        relu2 = tf.maximum(0.2 * bn2, bn2)
        
        x3 = tf.layers.conv2d(relu2, 256, 5, strides=2, padding='same')
        bn3 = tf.layers.batch_normalization(x3, training=True)
        relu3 = tf.maximum(0.2 * bn3, bn3)
        
        flatten = tf.reshape(relu3, (-1, 4*4*256))
        logits = tf.layers.dense(flatten, 1)
        out = tf.sigmoid(logits)
        
        return (out, logits)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(discriminator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### 生成器（Generator）
# 部署 `generator` 函数以使用 `z` 生成图像。该函数应能够重复使用神经网络中的各种变量。
# 在 [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) 中使用 "generator" 的变量空间名来重复使用该函数中的变量。
#
# 该函数应返回所生成的 28 x 28 x `out_channel_dim` 维度图像。

# %%
def generator(z, out_channel_dim, is_train=True):
    """
    Create the generator network
    :param z: Input z
    :param out_channel_dim: The number of channels in the output image
    :param is_train: Boolean if generator is being used for training
    :return: The tensor output of the generator
    """
    # TODO: Implement Function
    #alpha = 0.2
    
    with tf.variable_scope('generator', reuse=not is_train):
        x1 = tf.layers.dense(z, 2*2*512)
        
        x1 = tf.reshape(x1, (-1, 2, 2, 512))
        x1 = tf.layers.batch_normalization(x1, training=is_train)
        x1 = tf.maximum(0.2 * x1, x1)
        
        x2 = tf.layers.conv2d_transpose(x1, 256, 5, strides=2, padding='valid')
        x2 = tf.layers.batch_normalization(x2, training=is_train)
        x2 = tf.maximum(0.2 * x2, x2)
        
        x3 = tf.layers.conv2d_transpose(x2, 128, 5, strides=2, padding='same')
        x3 = tf.layers.batch_normalization(x3, training=is_train)
        x3 = tf.maximum(0.2 * x3, x3)
        
        logits = tf.layers.conv2d_transpose(x3, out_channel_dim, 5, strides=2, padding='same')
        
        out = tf.tanh(logits)
        
        return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(generator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### 损失函数（Loss）
# 部署 `model_loss` 函数训练并计算 GANs 的损失。该函数应返回形如 (discriminator loss, generator loss) 的元组。
#
# 使用你已实现的函数：
# - `discriminator(images, reuse=False)`
# - `generator(z, out_channel_dim, is_train=True)`

# %%
def model_loss(input_real, input_z, out_channel_dim):
    """
    Get the loss for the discriminator and generator
    :param input_real: Images from the real dataset
    :param input_z: Z input
    :param out_channel_dim: The number of channels in the output image
    :return: A tuple of (discriminator loss, generator loss)
    """
    # TODO: Implement Function
    
    g_out = generator(input_z, out_channel_dim)
    d_real_out, d_real_logits = discriminator(input_real)
    d_fake_out, d_fake_logits = discriminator(g_out, reuse=True)
    
    d_loss_real = tf.reduce_mean(
                        tf.nn.sigmoid_cross_entropy_with_logits(
                                    logits=d_real_logits,
                                    labels=tf.ones_like(d_real_out)))
    
    d_loss_fake = tf.reduce_mean(
                        tf.nn.sigmoid_cross_entropy_with_logits(
                                    logits=d_fake_logits,
                                    labels=tf.zeros_like(d_fake_out)))
    
    d_loss = d_loss_real + d_loss_fake
    
    g_loss = tf.reduce_mean(
             tf.nn.sigmoid_cross_entropy_with_logits(
                                     logits=d_fake_logits,
                                     labels=tf.ones_like(d_fake_out)))
    return d_loss, g_loss


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_loss(model_loss)
# Out:
# Tests Passed

# %% [markdown]
# ### 优化（Optimization）
# 部署 `model_opt` 函数实现对 GANs 的优化。使用 [`tf.trainable_variables`](https://www.tensorflow.org/api_docs/python/tf/trainable_variables) 获取可训练的所有变量。通过变量空间名 `discriminator` 和 `generator` 来过滤变量。该函数应返回形如 (discriminator training operation, generator training operation) 的元组。

# %%
def model_opt(d_loss, g_loss, learning_rate, beta1):
    """
    Get optimization operations
    :param d_loss: Discriminator loss Tensor
    :param g_loss: Generator loss Tensor
    :param learning_rate: Learning Rate Placeholder
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :return: A tuple of (discriminator training operation, generator training operation)
    """
    # TODO: Implement Function
    all_vars = tf.trainable_variables()
    g_vars = [var for var in all_vars if var.name.startswith('generator')]
    d_vars = [var for var in all_vars if var.name.startswith('discriminator')]
    
    d_train_opt = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(d_loss, var_list=d_vars)
    g_train_opt = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(g_loss, var_list=g_vars)
    
    return d_train_opt, g_train_opt


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_opt(model_opt, tf)
# Out:
# Tests Passed

# %% [markdown]
# ## 训练神经网络（Neural Network Training）
# ### 输出显示
# 使用该函数可以显示生成器 (Generator) 在训练过程中的当前输出，这会帮你评估 GANs 模型的训练程度。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

def show_generator_output(sess, n_images, input_z, out_channel_dim, image_mode):
    """
    Show example output for the generator
    :param sess: TensorFlow session
    :param n_images: Number of Images to display
    :param input_z: Input Z Tensor
    :param out_channel_dim: The number of channels in the output image
    :param image_mode: The mode to use for images ("RGB" or "L")
    """
    cmap = None if image_mode == 'RGB' else 'gray'
    z_dim = input_z.get_shape().as_list()[-1]
    example_z = np.random.uniform(-1, 1, size=[n_images, z_dim])

    samples = sess.run(
        generator(input_z, out_channel_dim, False),
        feed_dict={input_z: example_z})

    images_grid = helper.images_square_grid(samples, image_mode)
    pyplot.imshow(images_grid, cmap=cmap)
    pyplot.show()

# %% [markdown]
# ### 训练
# 部署 `train` 函数以建立并训练 GANs 模型。记得使用以下你已完成的函数：
# - `model_inputs(image_width, image_height, image_channels, z_dim)`
# - `model_loss(input_real, input_z, out_channel_dim)`
# - `model_opt(d_loss, g_loss, learning_rate, beta1)`
#
# 使用 `show_generator_output` 函数显示 `generator` 在训练过程中的输出。
#
# **注意**：在每个批次 (batch) 中运行 `show_generator_output` 函数会显著增加训练时间与该 notebook 的体积。推荐每 100 批次输出一次 `generator` 的输出。

# %%
def train(epoch_count, batch_size, z_dim, learning_rate, beta1, get_batches, data_shape, data_image_mode):
    """
    Train the GAN
    :param epoch_count: Number of epochs
    :param batch_size: Batch Size
    :param z_dim: Z dimension
    :param learning_rate: Learning Rate
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :param get_batches: Function to get batches
    :param data_shape: Shape of the data
    :param data_image_mode: The image mode to use for images ("RGB" or "L")
    """
    # TODO: Build Model
    #tf.reset_default_graph()
    
    input_real, input_z, learn_rate = model_inputs(data_shape[1],data_shape[2],data_shape[3], z_dim)
    d_loss, g_loss = model_loss(input_real, input_z, data_shape[3])
    d_opt, g_opt = model_opt(d_loss, g_loss, learning_rate, beta1)
    
    steps = 0
    
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for epoch_i in range(epoch_count):
            for batch_images in get_batches(batch_size):
                # TODO: Train Model
                #(-0.5 to 0.5)
                steps += 1
                
                image_input = batch_images * 2 
                
                batch_z = np.random.uniform(-1, 1, size=(batch_size, z_dim))
                
                _ = sess.run(d_opt, feed_dict={input_real: image_input, 
                                               input_z: batch_z, 
                                               learn_rate:learning_rate})
                
                _ = sess.run(g_opt, feed_dict={input_real: image_input, 
                                               input_z: batch_z, 
                                               learn_rate:learning_rate})
                
                
                loss_d_train = d_loss.eval({input_z:batch_z,
                                            input_real:image_input})
                
                loss_g_trian = g_loss.eval({input_z:batch_z})
                
                if steps % 10 == 0:
                    print("Epoch {}/{}...".format(epoch_i+1, epochs),
                           "Discriminator Loss: {:.4f}...".format(loss_d_train),
                           "Generator Loss: {:.4f}".format(loss_g_trian))   
                
                if steps % 100 == 0:
                    show_generator_output(sess, 16, input_z, data_shape[3], data_image_mode)
                    
            show_generator_output(sess, 16, input_z, data_shape[3], data_image_mode)

# %% [markdown]
# ### MNIST
# 在 MNIST 上测试你的 GANs 模型。经过 2 次迭代，GANs 应该能够生成类似手写数字的图像。确保生成器 (generator) 低于辨别器 (discriminator) 的损失，或接近 0。

# %%
batch_size = 128
z_dim = 100
learning_rate = 0.001
beta1 = 0.5


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 2

mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
          mnist_dataset.shape, mnist_dataset.image_mode)
# Out:
# Epoch 1/2... Discriminator Loss: 0.0353... Generator Loss: 3.7185
# Epoch 1/2... Discriminator Loss: 0.8068... Generator Loss: 1.1386
# Epoch 1/2... Discriminator Loss: 0.2232... Generator Loss: 4.2196
# Epoch 1/2... Discriminator Loss: 0.7177... Generator Loss: 4.2256
# Epoch 1/2... Discriminator Loss: 0.2395... Generator Loss: 3.8909
# Epoch 1/2... Discriminator Loss: 0.8711... Generator Loss: 0.8958
# Epoch 1/2... Discriminator Loss: 0.4720... Generator Loss: 2.0322
# Epoch 1/2... Discriminator Loss: 0.2343... Generator Loss: 4.5340
# Epoch 1/2... Discriminator Loss: 0.3034... Generator Loss: 2.2293
# Epoch 1/2... Discriminator Loss: 0.3990... Generator Loss: 3.6396
# Epoch 1/2... Discriminator Loss: 0.1605... Generator Loss: 4.4861
# Epoch 1/2... Discriminator Loss: 1.5469... Generator Loss: 9.3399
# Epoch 1/2... Discriminator Loss: 0.4238... Generator Loss: 3.4419
# Epoch 1/2... Discriminator Loss: 0.0604... Generator Loss: 3.8699
# Epoch 1/2... Discriminator Loss: 0.2628... Generator Loss: 1.9895
# Epoch 1/2... Discriminator Loss: 3.0990... Generator Loss: 14.1352
# Epoch 1/2... Discriminator Loss: 0.2188... Generator Loss: 3.1787
# Epoch 1/2... Discriminator Loss: 0.1035... Generator Loss: 3.0086
# Epoch 1/2... Discriminator Loss: 0.1719... Generator Loss: 2.7960
# Epoch 1/2... Discriminator Loss: 0.1729... Generator Loss: 3.1031
# Epoch 1/2... Discriminator Loss: 0.3680... Generator Loss: 2.1157
# Epoch 1/2... Discriminator Loss: 0.6041... Generator Loss: 5.4281
# Epoch 1/2... Discriminator Loss: 0.7782... Generator Loss: 1.6372
# Epoch 1/2... Discriminator Loss: 0.4930... Generator Loss: 2.4728
# Epoch 1/2... Discriminator Loss: 0.4290... Generator Loss: 3.1505
# Epoch 1/2... Discriminator Loss: 0.4318... Generator Loss: 1.8177
# Epoch 1/2... Discriminator Loss: 1.0433... Generator Loss: 3.8488
# Epoch 1/2... Discriminator Loss: 0.8905... Generator Loss: 0.9705
# Epoch 1/2... Discriminator Loss: 0.3668... Generator Loss: 3.3695
# Epoch 1/2... Discriminator Loss: 0.6034... Generator Loss: 1.8157
# Epoch 1/2... Discriminator Loss: 0.4081... Generator Loss: 2.7309
# Epoch 1/2... Discriminator Loss: 0.3214... Generator Loss: 3.0096
# Epoch 1/2... Discriminator Loss: 0.3499... Generator Loss: 1.9718
# Epoch 1/2... Discriminator Loss: 0.4513... Generator Loss: 1.6506
# Epoch 1/2... Discriminator Loss: 0.3828... Generator Loss: 3.6769
# Epoch 1/2... Discriminator Loss: 0.2333... Generator Loss: 2.2867
# Epoch 1/2... Discriminator Loss: 1.4961... Generator Loss: 9.7422
# Epoch 1/2... Discriminator Loss: 0.2541... Generator Loss: 3.5573
# Epoch 1/2... Discriminator Loss: 0.5429... Generator Loss: 2.9757
# Epoch 1/2... Discriminator Loss: 0.3106... Generator Loss: 2.4242
# Epoch 1/2... Discriminator Loss: 0.7908... Generator Loss: 5.5116
# Epoch 1/2... Discriminator Loss: 1.6398... Generator Loss: 0.3718
# Epoch 1/2... Discriminator Loss: 0.4058... Generator Loss: 2.0673
# Epoch 1/2... Discriminator Loss: 0.5914... Generator Loss: 1.2664
# Epoch 1/2... Discriminator Loss: 0.4972... Generator Loss: 1.9382
# Epoch 1/2... Discriminator Loss: 1.1118... Generator Loss: 4.8909
# Epoch 2/2... Discriminator Loss: 0.3824... Generator Loss: 2.3597
# Epoch 2/2... Discriminator Loss: 1.1194... Generator Loss: 2.5199
# Epoch 2/2... Discriminator Loss: 0.8060... Generator Loss: 0.9868
# Epoch 2/2... Discriminator Loss: 0.5113... Generator Loss: 2.0915
# Epoch 2/2... Discriminator Loss: 0.6695... Generator Loss: 2.1410
# Epoch 2/2... Discriminator Loss: 1.0570... Generator Loss: 0.7068
# Epoch 2/2... Discriminator Loss: 0.6520... Generator Loss: 2.0324
# Epoch 2/2... Discriminator Loss: 1.1655... Generator Loss: 0.6251
# Epoch 2/2... Discriminator Loss: 0.6968... Generator Loss: 3.0719
# Epoch 2/2... Discriminator Loss: 0.5847... Generator Loss: 3.1864
# Epoch 2/2... Discriminator Loss: 0.6303... Generator Loss: 2.5709
# Epoch 2/2... Discriminator Loss: 0.6592... Generator Loss: 2.3471
# Epoch 2/2... Discriminator Loss: 1.2945... Generator Loss: 2.2038
# Epoch 2/2... Discriminator Loss: 0.8164... Generator Loss: 2.2139
# Epoch 2/2... Discriminator Loss: 0.8657... Generator Loss: 2.3851
# Epoch 2/2... Discriminator Loss: 0.6994... Generator Loss: 1.1704
# Epoch 2/2... Discriminator Loss: 1.3847... Generator Loss: 0.4894
# Epoch 2/2... Discriminator Loss: 0.8366... Generator Loss: 1.1657
# Epoch 2/2... Discriminator Loss: 0.9651... Generator Loss: 0.7933
# Epoch 2/2... Discriminator Loss: 0.9794... Generator Loss: 1.0870
# Epoch 2/2... Discriminator Loss: 0.7582... Generator Loss: 2.2828
# Epoch 2/2... Discriminator Loss: 0.8307... Generator Loss: 1.0398
# Epoch 2/2... Discriminator Loss: 0.8402... Generator Loss: 0.9957
# Epoch 2/2... Discriminator Loss: 0.9136... Generator Loss: 0.9957
# Epoch 2/2... Discriminator Loss: 0.7839... Generator Loss: 1.8122
# Epoch 2/2... Discriminator Loss: 0.5988... Generator Loss: 1.8600
# Epoch 2/2... Discriminator Loss: 0.6905... Generator Loss: 1.4709
# Epoch 2/2... Discriminator Loss: 0.6769... Generator Loss: 1.9923
# Epoch 2/2... Discriminator Loss: 0.8657... Generator Loss: 1.2070
# Epoch 2/2... Discriminator Loss: 0.7426... Generator Loss: 1.6414
# Epoch 2/2... Discriminator Loss: 0.8165... Generator Loss: 1.3745
# Epoch 2/2... Discriminator Loss: 0.9030... Generator Loss: 2.4356
# Epoch 2/2... Discriminator Loss: 0.7859... Generator Loss: 1.2418
# Epoch 2/2... Discriminator Loss: 0.9315... Generator Loss: 2.2935
# Epoch 2/2... Discriminator Loss: 0.9604... Generator Loss: 0.9012
# Epoch 2/2... Discriminator Loss: 0.8552... Generator Loss: 1.9278
# Epoch 2/2... Discriminator Loss: 0.6527... Generator Loss: 1.7356
# Epoch 2/2... Discriminator Loss: 0.7975... Generator Loss: 1.4424
# Epoch 2/2... Discriminator Loss: 1.0184... Generator Loss: 0.7442
# Epoch 2/2... Discriminator Loss: 0.8743... Generator Loss: 1.4662
# Epoch 2/2... Discriminator Loss: 0.9458... Generator Loss: 1.9400
# Epoch 2/2... Discriminator Loss: 0.7415... Generator Loss: 1.8238
# Epoch 2/2... Discriminator Loss: 0.7829... Generator Loss: 1.8647
# Epoch 2/2... Discriminator Loss: 0.8049... Generator Loss: 2.1333
# Epoch 2/2... Discriminator Loss: 1.0553... Generator Loss: 0.7248
# Epoch 2/2... Discriminator Loss: 1.0849... Generator Loss: 2.9082
# Epoch 2/2... Discriminator Loss: 0.8647... Generator Loss: 1.6500

# %% [markdown]
# ### CelebA
# 在 CelebA 上运行你的 GANs 模型。在一般的GPU上运行每次迭代大约需要 20 分钟。你可以运行整个迭代，或者当 GANs 开始产生真实人脸图像时停止它。

# %%
batch_size = 128
z_dim = 100
learning_rate = 0.0001
beta1 = 0.45


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 1

celeba_dataset = helper.Dataset('celeba', glob(os.path.join(data_dir, 'img_align_celeba/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, celeba_dataset.get_batches,
          celeba_dataset.shape, celeba_dataset.image_mode)
# Out:
# Epoch 1/1... Discriminator Loss: 1.2821... Generator Loss: 0.6578
# Epoch 1/1... Discriminator Loss: 0.7709... Generator Loss: 1.0631
# Epoch 1/1... Discriminator Loss: 0.5462... Generator Loss: 1.4666
# Epoch 1/1... Discriminator Loss: 0.4370... Generator Loss: 1.8109
# Epoch 1/1... Discriminator Loss: 0.4175... Generator Loss: 1.9880
# Epoch 1/1... Discriminator Loss: 0.2860... Generator Loss: 2.0270
# Epoch 1/1... Discriminator Loss: 0.2901... Generator Loss: 2.1959
# Epoch 1/1... Discriminator Loss: 0.2316... Generator Loss: 2.3065
# Epoch 1/1... Discriminator Loss: 0.2747... Generator Loss: 2.3978
# Epoch 1/1... Discriminator Loss: 0.2254... Generator Loss: 2.3222
# Epoch 1/1... Discriminator Loss: 0.4996... Generator Loss: 1.2073
# Epoch 1/1... Discriminator Loss: 0.1516... Generator Loss: 2.7651
# Epoch 1/1... Discriminator Loss: 0.1816... Generator Loss: 2.6089
# Epoch 1/1... Discriminator Loss: 0.2230... Generator Loss: 2.6563
# Epoch 1/1... Discriminator Loss: 0.2441... Generator Loss: 2.3729
# Epoch 1/1... Discriminator Loss: 0.3198... Generator Loss: 1.7183
# Epoch 1/1... Discriminator Loss: 0.2209... Generator Loss: 6.7174
# Epoch 1/1... Discriminator Loss: 0.2199... Generator Loss: 2.5633
# Epoch 1/1... Discriminator Loss: 0.1771... Generator Loss: 2.5027
# Epoch 1/1... Discriminator Loss: 0.2779... Generator Loss: 2.4034
# Epoch 1/1... Discriminator Loss: 0.2470... Generator Loss: 3.6546
# Epoch 1/1... Discriminator Loss: 1.3739... Generator Loss: 4.5798
# Epoch 1/1... Discriminator Loss: 0.6945... Generator Loss: 2.0729
# Epoch 1/1... Discriminator Loss: 0.4045... Generator Loss: 1.8486
# Epoch 1/1... Discriminator Loss: 0.6207... Generator Loss: 1.5187
# Epoch 1/1... Discriminator Loss: 0.2289... Generator Loss: 2.5817
# Epoch 1/1... Discriminator Loss: 0.4247... Generator Loss: 2.0398
# Epoch 1/1... Discriminator Loss: 0.3354... Generator Loss: 2.2704
# Epoch 1/1... Discriminator Loss: 0.3703... Generator Loss: 1.9470
# Epoch 1/1... Discriminator Loss: 0.4655... Generator Loss: 1.9034
# Epoch 1/1... Discriminator Loss: 0.4730... Generator Loss: 1.5046
# Epoch 1/1... Discriminator Loss: 0.4243... Generator Loss: 1.7524
# Epoch 1/1... Discriminator Loss: 0.9592... Generator Loss: 0.7559
# Epoch 1/1... Discriminator Loss: 0.6624... Generator Loss: 1.3151
# Epoch 1/1... Discriminator Loss: 0.3975... Generator Loss: 2.1217
# Epoch 1/1... Discriminator Loss: 0.5172... Generator Loss: 1.9934
# Epoch 1/1... Discriminator Loss: 0.7411... Generator Loss: 2.3641
# Epoch 1/1... Discriminator Loss: 0.5891... Generator Loss: 1.5732
# Epoch 1/1... Discriminator Loss: 0.4963... Generator Loss: 2.7127
# Epoch 1/1... Discriminator Loss: 0.7874... Generator Loss: 1.9370
# Epoch 1/1... Discriminator Loss: 0.7683... Generator Loss: 1.7620
# Epoch 1/1... Discriminator Loss: 1.2901... Generator Loss: 3.4872
# Epoch 1/1... Discriminator Loss: 0.6863... Generator Loss: 1.4958
# Epoch 1/1... Discriminator Loss: 0.7280... Generator Loss: 1.5729
# Epoch 1/1... Discriminator Loss: 1.0572... Generator Loss: 1.2045
# Epoch 1/1... Discriminator Loss: 0.7397... Generator Loss: 2.0293
# Epoch 1/1... Discriminator Loss: 1.0985... Generator Loss: 0.5606
# Epoch 1/1... Discriminator Loss: 0.7918... Generator Loss: 1.0636
# Epoch 1/1... Discriminator Loss: 0.7203... Generator Loss: 2.3376
# Epoch 1/1... Discriminator Loss: 0.6859... Generator Loss: 1.3897
# Epoch 1/1... Discriminator Loss: 0.5789... Generator Loss: 1.6197
# Epoch 1/1... Discriminator Loss: 0.7852... Generator Loss: 2.1077
# Epoch 1/1... Discriminator Loss: 0.7254... Generator Loss: 1.5210
# Epoch 1/1... Discriminator Loss: 0.7470... Generator Loss: 1.6340
# Epoch 1/1... Discriminator Loss: 0.7894... Generator Loss: 1.8872
# Epoch 1/1... Discriminator Loss: 0.7350... Generator Loss: 1.1733
# Epoch 1/1... Discriminator Loss: 1.0051... Generator Loss: 1.8509
# Epoch 1/1... Discriminator Loss: 0.8123... Generator Loss: 1.3987
# Epoch 1/1... Discriminator Loss: 0.6825... Generator Loss: 1.3375
# Epoch 1/1... Discriminator Loss: 0.9861... Generator Loss: 1.3772
# Epoch 1/1... Discriminator Loss: 1.1822... Generator Loss: 0.8140
# Epoch 1/1... Discriminator Loss: 0.8667... Generator Loss: 1.3149
# Epoch 1/1... Discriminator Loss: 0.6865... Generator Loss: 1.6712
# Epoch 1/1... Discriminator Loss: 0.7866... Generator Loss: 1.5777
# Epoch 1/1... Discriminator Loss: 0.8096... Generator Loss: 1.0314
# Epoch 1/1... Discriminator Loss: 0.8039... Generator Loss: 1.3082
# Epoch 1/1... Discriminator Loss: 0.8259... Generator Loss: 1.2380
# Epoch 1/1... Discriminator Loss: 0.8016... Generator Loss: 1.4997
# Epoch 1/1... Discriminator Loss: 0.9378... Generator Loss: 1.0591
# Epoch 1/1... Discriminator Loss: 0.8472... Generator Loss: 0.9480
# Epoch 1/1... Discriminator Loss: 0.8460... Generator Loss: 1.0485
# Epoch 1/1... Discriminator Loss: 0.8972... Generator Loss: 1.6143
# Epoch 1/1... Discriminator Loss: 0.9517... Generator Loss: 0.8763
# Epoch 1/1... Discriminator Loss: 0.9884... Generator Loss: 1.2671
# Epoch 1/1... Discriminator Loss: 0.8253... Generator Loss: 1.5453
# Epoch 1/1... Discriminator Loss: 0.8779... Generator Loss: 1.3942
# Epoch 1/1... Discriminator Loss: 1.0688... Generator Loss: 1.3690
# Epoch 1/1... Discriminator Loss: 0.8255... Generator Loss: 1.1922
# Epoch 1/1... Discriminator Loss: 0.7800... Generator Loss: 1.2086
# Epoch 1/1... Discriminator Loss: 0.8362... Generator Loss: 0.9470
# Epoch 1/1... Discriminator Loss: 0.8778... Generator Loss: 1.0484
# Epoch 1/1... Discriminator Loss: 1.0220... Generator Loss: 0.7628
# Epoch 1/1... Discriminator Loss: 0.9026... Generator Loss: 0.9026
# Epoch 1/1... Discriminator Loss: 0.7715... Generator Loss: 1.5198
# Epoch 1/1... Discriminator Loss: 0.7980... Generator Loss: 1.8197
# Epoch 1/1... Discriminator Loss: 1.0741... Generator Loss: 1.0542
# Epoch 1/1... Discriminator Loss: 1.0677... Generator Loss: 1.7728
# Epoch 1/1... Discriminator Loss: 0.7527... Generator Loss: 1.3640
# Epoch 1/1... Discriminator Loss: 0.8247... Generator Loss: 1.6381
# Epoch 1/1... Discriminator Loss: 0.9026... Generator Loss: 1.0656
# Epoch 1/1... Discriminator Loss: 1.0123... Generator Loss: 0.9340
# Epoch 1/1... Discriminator Loss: 1.1950... Generator Loss: 0.8221
# Epoch 1/1... Discriminator Loss: 1.0393... Generator Loss: 0.9255
# Epoch 1/1... Discriminator Loss: 1.3490... Generator Loss: 0.7138
# Epoch 1/1... Discriminator Loss: 1.0345... Generator Loss: 1.1361
# Epoch 1/1... Discriminator Loss: 1.5028... Generator Loss: 0.4759
# Epoch 1/1... Discriminator Loss: 1.0046... Generator Loss: 1.0870
# Epoch 1/1... Discriminator Loss: 0.9309... Generator Loss: 1.3282
# Epoch 1/1... Discriminator Loss: 0.9070... Generator Loss: 1.2107
# Epoch 1/1... Discriminator Loss: 0.8746... Generator Loss: 0.8735
# Epoch 1/1... Discriminator Loss: 0.9656... Generator Loss: 1.1220
# Epoch 1/1... Discriminator Loss: 0.8976... Generator Loss: 1.0208
# Epoch 1/1... Discriminator Loss: 1.1008... Generator Loss: 0.8071
# Epoch 1/1... Discriminator Loss: 1.1129... Generator Loss: 0.9119
# Epoch 1/1... Discriminator Loss: 0.9034... Generator Loss: 1.1984
# Epoch 1/1... Discriminator Loss: 1.0332... Generator Loss: 0.6908
# Epoch 1/1... Discriminator Loss: 1.0515... Generator Loss: 0.7765
# Epoch 1/1... Discriminator Loss: 0.8902... Generator Loss: 0.9777
# Epoch 1/1... Discriminator Loss: 1.0160... Generator Loss: 1.0468
# Epoch 1/1... Discriminator Loss: 0.9130... Generator Loss: 1.0761
# Epoch 1/1... Discriminator Loss: 0.8865... Generator Loss: 1.9726
# Epoch 1/1... Discriminator Loss: 0.9716... Generator Loss: 1.6952
# Epoch 1/1... Discriminator Loss: 0.9706... Generator Loss: 1.2741
# Epoch 1/1... Discriminator Loss: 0.9665... Generator Loss: 0.9086
# Epoch 1/1... Discriminator Loss: 0.8857... Generator Loss: 1.0707
# Epoch 1/1... Discriminator Loss: 1.0899... Generator Loss: 1.0602
# Epoch 1/1... Discriminator Loss: 0.8797... Generator Loss: 1.1159
# Epoch 1/1... Discriminator Loss: 0.9734... Generator Loss: 0.9104
# Epoch 1/1... Discriminator Loss: 0.9751... Generator Loss: 0.9589
# Epoch 1/1... Discriminator Loss: 1.0168... Generator Loss: 1.5033
# Epoch 1/1... Discriminator Loss: 0.9397... Generator Loss: 0.8950
# Epoch 1/1... Discriminator Loss: 0.8385... Generator Loss: 1.3853
# Epoch 1/1... Discriminator Loss: 1.1553... Generator Loss: 1.2286
# Epoch 1/1... Discriminator Loss: 0.8520... Generator Loss: 1.8910
# Epoch 1/1... Discriminator Loss: 0.9623... Generator Loss: 1.2847
# Epoch 1/1... Discriminator Loss: 0.8004... Generator Loss: 1.4461
# Epoch 1/1... Discriminator Loss: 0.8944... Generator Loss: 1.2254
# Epoch 1/1... Discriminator Loss: 1.2223... Generator Loss: 1.8387
# Epoch 1/1... Discriminator Loss: 0.8057... Generator Loss: 1.8884
# Epoch 1/1... Discriminator Loss: 0.9138... Generator Loss: 1.2227
# Epoch 1/1... Discriminator Loss: 0.9853... Generator Loss: 0.9280
# Epoch 1/1... Discriminator Loss: 1.0503... Generator Loss: 1.3175
# Epoch 1/1... Discriminator Loss: 0.9466... Generator Loss: 1.7037
# Epoch 1/1... Discriminator Loss: 1.0852... Generator Loss: 0.7029
# Epoch 1/1... Discriminator Loss: 0.9963... Generator Loss: 1.0540
# Epoch 1/1... Discriminator Loss: 0.9827... Generator Loss: 0.9971
# Epoch 1/1... Discriminator Loss: 0.8893... Generator Loss: 1.2168
# Epoch 1/1... Discriminator Loss: 1.2272... Generator Loss: 0.8339
# Epoch 1/1... Discriminator Loss: 0.9150... Generator Loss: 1.2120
# Epoch 1/1... Discriminator Loss: 1.2676... Generator Loss: 2.0987
# Epoch 1/1... Discriminator Loss: 1.0473... Generator Loss: 1.1146
# Epoch 1/1... Discriminator Loss: 1.3292... Generator Loss: 0.5349
# Epoch 1/1... Discriminator Loss: 0.9509... Generator Loss: 1.0656
# Epoch 1/1... Discriminator Loss: 0.9191... Generator Loss: 1.3612
# Epoch 1/1... Discriminator Loss: 0.9489... Generator Loss: 1.0850
# Epoch 1/1... Discriminator Loss: 1.0387... Generator Loss: 1.1763
# Epoch 1/1... Discriminator Loss: 1.0917... Generator Loss: 0.8216
# Epoch 1/1... Discriminator Loss: 0.7986... Generator Loss: 1.7300
# Epoch 1/1... Discriminator Loss: 0.9357... Generator Loss: 0.9327
# Epoch 1/1... Discriminator Loss: 1.0918... Generator Loss: 1.2394
# Epoch 1/1... Discriminator Loss: 1.2770... Generator Loss: 1.1222
# Epoch 1/1... Discriminator Loss: 1.0134... Generator Loss: 1.0718
# Epoch 1/1... Discriminator Loss: 1.0920... Generator Loss: 0.6673
# Epoch 1/1... Discriminator Loss: 0.8497... Generator Loss: 1.1269
# Epoch 1/1... Discriminator Loss: 1.1086... Generator Loss: 1.6250
# Epoch 1/1... Discriminator Loss: 0.7779... Generator Loss: 1.4569
# Epoch 1/1... Discriminator Loss: 1.0179... Generator Loss: 1.3973
# Epoch 1/1... Discriminator Loss: 0.8782... Generator Loss: 1.2284

# %% [markdown]
# ### 提交项目
# 提交本项目前，确保运行所有 cells 后保存该文件。
#
# 保存该文件为 "dlnd_face_generation.ipynb"， 并另存为 HTML 格式 "File" -> "Download as"。提交项目时请附带 "helper.py" 和 "problem_unittests.py" 文件。
